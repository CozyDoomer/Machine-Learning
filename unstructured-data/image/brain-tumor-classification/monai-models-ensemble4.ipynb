# %% [markdown]
# ## Use stacked images (3D) and Densenet121 3D model
#
# Acknowledgements:
#
# - https://www.kaggle.com/rluethy/efficientnet3d-with-one-mri-type
# - https://www.kaggle.com/davidbroberts/determining-dicom-image-order
# - https://www.kaggle.com/ihelon/brain-tumor-eda-with-animations-and-modeling
# - https://www.kaggle.com/furcifer/torch-efficientnet3d-for-mri-no-train
# - https://github.com/shijianjian/EfficientNet-PyTorch-3D
#
# This notebook is based on the implementation of Densenet121 3D available here:
# https://www.kaggle.com/mikecho/monai-v060-deep-learning-in-healthcare-imaging
#
# It builds 4 models with only one MRI type, then ensembles all of them computing average probabilities

# %%
# !pip install torchio
# Out:
# Requirement already satisfied: torchio in /home/christian/miniconda/envs/pytorch/lib/python3.8/site-packages (0.18.56)
# Requirement already satisfied: scipy in /home/christian/miniconda/envs/pytorch/lib/python3.8/site-packages (from torchio) (1.7.1)
# Requirement already satisfied: torch>=1.1 in /home/christian/miniconda/envs/pytorch/lib/python3.8/site-packages (from torchio) (1.10.0.dev20210914)
# Requirement already satisfied: Deprecated in /home/christian/miniconda/envs/pytorch/lib/python3.8/site-packages (from torchio) (1.2.13)
# Requirement already satisfied: tqdm in /home/christian/miniconda/envs/pytorch/lib/python3.8/site-packages (from torchio) (4.62.2)
# Requirement already satisfied: click in /home/christian/miniconda/envs/pytorch/lib/python3.8/site-packages (from torchio) (8.0.1)
# Requirement already satisfied: nibabel in /home/christian/miniconda/envs/pytorch/lib/python3.8/site-packages (from torchio) (3.2.1)
# Requirement already satisfied: numpy>=1.15 in /home/christian/miniconda/envs/pytorch/lib/python3.8/site-packages (from torchio) (1.21.2)
# Requirement already satisfied: SimpleITK!=2.0.* in /home/christian/miniconda/envs/pytorch/lib/python3.8/site-packages (from torchio) (2.1.1)
# Requirement already satisfied: humanize in /home/christian/miniconda/envs/pytorch/lib/python3.8/site-packages (from torchio) (3.11.0)
# Requirement already satisfied: typing_extensions in /home/christian/miniconda/envs/pytorch/lib/python3.8/site-packages (from torch>=1.1->torchio) (3.10.0.2)
# Requirement already satisfied: wrapt<2,>=1.10 in /home/christian/miniconda/envs/pytorch/lib/python3.8/site-packages (from Deprecated->torchio) (1.12.1)
# Requirement already satisfied: setuptools in /home/christian/miniconda/envs/pytorch/lib/python3.8/site-packages (from humanize->torchio) (52.0.0.post20210125)
# Requirement already satisfied: packaging>=14.3 in /home/christian/miniconda/envs/pytorch/lib/python3.8/site-packages (from nibabel->torchio) (21.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /home/christian/miniconda/envs/pytorch/lib/python3.8/site-packages (from packaging>=14.3->nibabel->torchio) (2.4.7)

# %%
import os
import sys 
import json
import glob
import random
import re
import collections
import time

import numpy as np
import pandas as pd
import pydicom
import cv2
import matplotlib.pyplot as plt
import seaborn as sns

import torch
from torch import nn
from torch.utils import data as torch_data
from sklearn import model_selection as sk_model_selection
from torch.nn import functional as torch_functional

import torchio as tio

from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import roc_auc_score

import xgboost as xgb

# %%
if os.path.exists("/kaggle/input/rsna-miccai-brain-tumor-radiogenomic-classification"):
    data_directory = "/kaggle/input/rsna-miccai-brain-tumor-radiogenomic-classification"
    input_monaipath = "/kaggle/input/monai-v060-deep-learning-in-healthcare-imaging/"
    landmarks_directory = "/kaggle/input/rsna-landmarks"
else:
    data_directory = "rsna-miccai-brain-tumor-radiogenomic-classification"
    input_monaipath = "monai-v060-deep-learning-in-healthcare-imaging"
    landmarks_directory = "rsna-landmarks"

model_paths = "models"
os.makedirs("models", exist_ok=True)

# %%
mri_types = ['FLAIR', 'T1w', 'T1wCE', 'T2w']
SIZE = 256
NUM_IMAGES = 64
BATCH_SIZE = 2
N_EPOCHS = 5
NUM_FOLDS = 5
SEED = 42
MIN_LR = 1e-6
LR = 0.0004
LR_DECAY = 0.9

sys.path.append(input_monaipath)

from monai.networks.nets.densenet import DenseNet121

# %%
TOTAL_EPOCHS = N_EPOCHS * len(mri_types) * NUM_FOLDS
TOTAL_EPOCHS
# Out:
# 100

# %% [markdown]
# ## Functions to load images

# %%
def load_dicom_image(path, img_size=SIZE):
    dicom = pydicom.read_file(path)
    data = dicom.pixel_array
    if np.min(data)==np.max(data):
        data = np.zeros((img_size,img_size))
        return data
    
    data = cv2.resize(data, (img_size, img_size))
    return data


def natural_sort(l): 
    convert = lambda text: int(text) if text.isdigit() else text.lower()
    alphanum_key = lambda key: [convert(c) for c in re.split('([0-9]+)', key)]
    return sorted(l, key=alphanum_key)


def load_dicom_images_3d(scan_id, num_imgs=NUM_IMAGES, img_size=SIZE, mri_type="FLAIR", split="train"):
    files = natural_sort(glob.glob(f"{data_directory}/{split}/{scan_id}/{mri_type}/*.dcm"))
    every_nth = len(files) / num_imgs
    indexes = [min(int(round(i*every_nth)), len(files)-1) for i in range(0,num_imgs)]
    
    files_to_load = [files[i] for i in indexes]
    
    img3d = np.stack([load_dicom_image(f) for f in files_to_load]).T 
    
    img3d = img3d - np.min(img3d)
    if np.max(img3d) != 0:
        img3d = img3d / np.max(img3d)
    
    return np.expand_dims(img3d,0)


load_dicom_images_3d("00000", mri_type=mri_types[0]).shape
# Out:
# (1, 256, 256, 64)

# %%
def set_seed(seed):
    random.seed(seed)
    os.environ["PYTHONHASHSEED"] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)
        torch.backends.cudnn.deterministic = True

set_seed(SEED)

# %% [markdown]
# ## remove samples as described in https://www.kaggle.com/c/rsna-miccai-brain-tumor-radiogenomic-classification/discussion/262046

# %%
samples_to_exclude = [109, 123, 709]

df = pd.read_csv(f"{data_directory}/train_labels.csv")
print("original shape", df.shape)
df = df[~df.BraTS21ID.isin(samples_to_exclude)]
print("new shape", df.shape)
display(df)
# Out:
# original shape (585, 2)
# new shape (582, 2)
#      BraTS21ID  MGMT_value
# 0            0           1
# 1            2           1
# 2            3           0
# 3            5           1
# 4            6           1
# ..         ...         ...
# 580       1005           1
# 581       1007           1
# 582       1008           1
# 583       1009           0
# 584       1010           0
#
# [582 rows x 2 columns]

# %%
# df = df.iloc[:16]

# %% [markdown]
# ## Model and training classes

# %%
class Dataset(torch_data.Dataset):
    def __init__(self, paths, targets=None, mri_type=None, landmarks_dict=None, split="train"):
        self.paths = paths
        self.targets = targets
        self.mri_type = mri_type
        self.landmarks_dict = landmarks_dict
        self.split = split
          
    def __len__(self):
        return len(self.paths)

    def __getitem__(self, index):
        scan_id = self.paths[index]
        if self.targets is None:
            data = load_dicom_images_3d(str(scan_id).zfill(5), mri_type=self.mri_type[index], split=self.split)
            augs = [
                tio.HistogramStandardization(self.landmarks_dict)
            ]
            transforms = tio.Compose(augs)
            data = transforms(data) 
        else:
            data = load_dicom_images_3d(str(scan_id).zfill(5), mri_type=self.mri_type[index], split="train")
            #get_foreground = tio.ZNormalization.mean
            augs = [
                tio.RandomAnisotropy(p=0.25),              # make images look anisotropic 25% of times
                tio.HistogramStandardization(self.landmarks_dict),
                # TODO: crop only sometimes! this happens all the time which is risky
                # tio.CropOrPad((256, 256, 64)),            # tight crop around brain
                # TODO: calculate landmarks:
                # https://colab.research.google.com/github/fepegar/torchio-notebooks/blob/main/notebooks/Data_preprocessing_and_augmentation_using_TorchIO_a_tutorial.ipynb#scrollTo=85COw2H63PfH
                # too strong? (removes part of the scan!)
                # tio.ZNormalization(
                #     masking_method=get_foreground),        # zero mean, unit variance of foreground
                #   works!
                tio.RandomBlur(p=0.25),                    # blur 25% of times
                tio.RandomNoise(p=0.25),                   # Gaussian noise 25% of times
                tio.OneOf({                                # either
                    tio.RandomAffine(): 0.8,               # random affine
                    tio.RandomElasticDeformation(): 0.2,   # or random elastic deformation
                }, p=0.8),                                 # applied to 80% of images
                tio.RandomBiasField(p=0.3),                # magnetic field inhomogeneity 30% of times
                tio.OneOf({                                # either
                    tio.RandomMotion(): 1,                 # random motion artifact
                    tio.RandomSpike(): 2,                  # or spikes
                    tio.RandomGhosting(): 2,               # or ghosts
                }, p=0.5),                                 # applied to 50% of images
            ]
            transforms = tio.Compose(augs)
            data = transforms(data)

            # import matplotlib.pyplot as plt
            # fig, axs = plt.subplots(2)
            # axs[0].imshow(data[0, :, :, 32], vmin=0, vmax=1)
            # print(data.shape)
            # data = transforms(data)
            # print(data.shape)
            # axs[1].imshow(data[0, :, :, 32], vmin=0, vmax=1)
            # plt.show()
            # print("============")
            
        if self.targets is None:
            return {"X": data, "id": scan_id}
        else:
            return {"X": data, "y": torch.tensor(self.targets[index], dtype=torch.float)}

# %%
def build_model():
    model = DenseNet121(spatial_dims=3, in_channels=1, out_channels=1)
    return model

# %%
class Trainer:
    def __init__(
        self, 
        model, 
        device, 
        optimizer, 
        criterion
    ):
        self.model = model
        self.device = device
        self.optimizer = optimizer
        self.lr_scheduler = torch.optim.lr_scheduler.CyclicLR(optimizer, base_lr=MIN_LR, max_lr=LR, cycle_momentum=False)
        # self.lr_scheduler = torch.optim.lr_scheduler.ExponentialLR(self.optimizer, gamma=LR_DECAY)
        self.criterion = criterion

        self.best_valid_score = .0
        self.n_patience = 0
        self.lastmodel = None
        
        self.val_losses = []
        self.train_losses = []
        self.val_auc = []
        
    def fit(self, epochs, train_loader, valid_loader, save_path, patience):      
        for n_epoch in range(1, epochs + 1):
            self.info_message("EPOCH: {}", n_epoch)
            
            train_loss, train_time = self.train_epoch(train_loader)
            valid_loss, valid_auc, valid_time = self.valid_epoch(valid_loader)
            
            self.train_losses.append(train_loss)
            self.val_losses.append(valid_loss)
            self.val_auc.append(valid_auc)
            
            self.info_message(
                "[Epoch Train: {}] loss: {:.4f}, time: {:.2f} s",
                n_epoch, train_loss, train_time
            )
            
            self.info_message(
                "[Epoch Valid: {}] loss: {:.4f}, auc: {:.4f}, time: {:.2f} s",
                n_epoch, valid_loss, valid_auc, valid_time
            )

            if self.best_valid_score < valid_auc: 
                self.save_model(n_epoch, save_path, valid_loss, valid_auc)
                self.info_message(
                     "auc improved from {:.4f} to {:.4f}. Saved model to '{}'", 
                    self.best_valid_score, valid_auc, self.lastmodel
                )
                self.best_valid_score = valid_auc
                self.n_patience = 0
            else:
                self.n_patience += 1
            
            if self.n_patience >= patience:
                self.info_message("\nValid auc didn't improve last {} epochs.", patience)
                break
            
    def train_epoch(self, train_loader):
        self.model.train()
        t = time.time()
        sum_loss = 0

        for step, batch in enumerate(train_loader, 1):
            X = batch["X"].clone().detach().float().to(self.device)
            targets = batch["y"].to(self.device)
            self.optimizer.zero_grad()
            outputs = self.model(X).squeeze(1)
            loss = self.criterion(outputs, targets)
                
            loss.backward()

            sum_loss += loss.detach().item()
            
            self.optimizer.step()
            # for param_group in self.optimizer.param_groups:
            #     print(param_group['lr'])
            
            message = 'Train Step {}/{}, train_loss: {:.4f}'
            self.info_message(message, step, len(train_loader), sum_loss/step, end="\r")
            
        self.lr_scheduler.step()
        
        return sum_loss/len(train_loader), int(time.time() - t)
    
    def valid_epoch(self, valid_loader):
        self.model.eval()
        t = time.time()
        sum_loss = 0
        y_all = []
        outputs_all = []

        for step, batch in enumerate(valid_loader, 1):
            with torch.no_grad():
                targets = batch["y"].to(self.device)

                output = torch.sigmoid(self.model(batch["X"].clone().detach().float().to(self.device)).squeeze(1))
                loss = self.criterion(output, targets)
                sum_loss += loss.detach().item()

                y_all.extend(batch["y"].tolist())
                outputs_all.extend(output.tolist())

            message = 'Valid Step {}/{}, valid_loss: {:.4f}'
            self.info_message(message, step, len(valid_loader), sum_loss/step, end="\r")
            
        y_all = [1 if x > 0.5 else 0 for x in y_all]
        auc = roc_auc_score(y_all, outputs_all)
        
        return sum_loss/len(valid_loader), auc, int(time.time() - t)
    
    def save_model(self, n_epoch, save_path, loss, auc):
        self.lastmodel = f"{save_path}-e{n_epoch}-loss{loss:.3f}-auc{auc:.3f}.pth"
        torch.save(
            {
                "model_state_dict": self.model.state_dict(),
                "optimizer_state_dict": self.optimizer.state_dict(),
                "best_valid_score": self.best_valid_score,
                "n_epoch": n_epoch,
            },
            self.lastmodel,
        )
        
    def display_plots(self, mri_type):
        plt.figure(figsize=(10,5))
        plt.title("{}: Training and Validation Loss")
        plt.plot(self.val_losses,label="val")
        plt.plot(self.train_losses,label="train")
        plt.xlabel("iterations")
        plt.ylabel("Loss")
        plt.legend()
        plt.show()
        plt.close()
        
        plt.figure(figsize=(10,5))
        plt.title("{}: Validation AUC-ROC")
        plt.plot(self.val_auc,label="val")
        plt.xlabel("iterations")
        plt.ylabel("AUC")
        plt.legend()
        plt.show()
        plt.close()
    
    @staticmethod
    def info_message(message, *args, end="\n"):
        print(message.format(*args), end=end)

# %% [markdown]
# # Prediction

# %%
def predict(model, df, mri_type, split):
    print("Predict:", mri_type, df.shape)
    df.loc[:,"MRI_Type"] = mri_type
    
    landmarks = torch.load(os.path.join(landmarks_directory, (f"{mri_type}_landmarks.npy")))
    landmarks_dict = {
        "default_image_name": landmarks,
    }

    data_retriever = Dataset(
        paths=df["BraTS21ID"].values,
        mri_type=df["MRI_Type"].values,
        split=split,
        landmarks_dict=landmarks_dict
    )

    data_loader = torch_data.DataLoader(
        data_retriever,
        batch_size=4,
        shuffle=False,
        num_workers=8,
    )
   
    model.eval()
    
    y_pred = []
    ids = []

    for e, batch in enumerate(data_loader,1):
        print(f"{e}/{len(data_loader)}", end="\r")
        with torch.no_grad():
            tmp_pred = torch.sigmoid(model(batch["X"].clone().detach().float().to(device)).squeeze(1)).cpu().numpy().squeeze()
            if tmp_pred.size == 1:
                y_pred.append(tmp_pred)
            else:
                y_pred.extend(tmp_pred.tolist())
            ids.extend(batch["id"].numpy().tolist())
            
    return y_pred

# %% [markdown]
# ## train loop

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

def train_mri_type(df, df_test, mri_type, skf):

    oof_train = np.zeros((len(df)))
    oof_test = np.zeros((len(df_test)))
    oof_test_skf = np.empty((5, len(df_test)))

    lastmodels = []
    for i, (train_index, val_index) in enumerate(skf.split(df, df["MGMT_value"], df["MGMT_value"])):
        df_train = df.iloc[train_index]
        df_valid = df.iloc[val_index]
        
        train = df_train.copy()
        valid = df_valid.copy()
        train.loc[:,"MRI_Type"] = mri_type
        valid.loc[:,"MRI_Type"] = mri_type

        print(train.shape, valid.shape)
        display(valid.head())
        print(len(train))
        display(valid.head())
        print(len(valid))

        landmarks = torch.load(os.path.join(landmarks_directory, (f"{mri_type}_landmarks.npy")))
        landmarks_dict = {
            "default_image_name": landmarks,
        }

        train_data_retriever = Dataset(
            train["BraTS21ID"].values, 
            train["MGMT_value"].values, 
            train["MRI_Type"].values,
            landmarks_dict=landmarks_dict
        )

        valid_data_retriever = Dataset(
            valid["BraTS21ID"].values, 
            valid["MGMT_value"].values,
            valid["MRI_Type"].values,
            landmarks_dict=landmarks_dict
        )

        train_loader = torch_data.DataLoader(
            train_data_retriever,
            batch_size=BATCH_SIZE,
            shuffle=True,
            num_workers=8,
        )

        valid_loader = torch_data.DataLoader(
            valid_data_retriever, 
            batch_size=BATCH_SIZE,
            shuffle=False,
            num_workers=8,
        )

        model = build_model()
        model.to(device)

        optimizer = torch.optim.Adam(model.parameters(), lr=LR)

        criterion = torch_functional.binary_cross_entropy_with_logits

        trainer = Trainer(
            model, 
            device, 
            optimizer, 
            criterion
        )

        history = trainer.fit(
            N_EPOCHS, 
            train_loader, 
            valid_loader, 
            f"models/{mri_type}", 
            N_EPOCHS,
        )

        trainer.display_plots(mri_type)

        oof_train[val_index] = predict(model, df_valid, mri_type, "train")
        oof_test_skf[i, :] = predict(model, df_test, mri_type, "test")

        lastmodels.append(trainer.lastmodel)

    oof_test = oof_test_skf.mean(axis=0)

    return oof_train, oof_test, lastmodels

# %%
df_test = pd.read_csv(f"{data_directory}/sample_submission.csv")
df_test["MGMT_value"] = 0

# %%
rkf = StratifiedKFold(n_splits=5, shuffle=True, random_state=21)

# %%
# %%time

oof_train = []
oof_test = []
modelfiles = []

for mri_type in mri_types:
    trn, tst, modelfile = train_mri_type(df, df_test, mri_type, rkf)
    oof_train.append(trn)
    oof_test.append(tst)
    modelfiles.append(modelfile)
# Out:
# (465, 3) (117, 3)
#     BraTS21ID  MGMT_value MRI_Type
# 2           3           0    FLAIR
# 9          14           1    FLAIR
# 11         18           0    FLAIR
# 18         26           1    FLAIR
# 24         35           1    FLAIR
# 465
#     BraTS21ID  MGMT_value MRI_Type
# 2           3           0    FLAIR
# 9          14           1    FLAIR
# 11         18           0    FLAIR
# 18         26           1    FLAIR
# 24         35           1    FLAIR
# 117
# EPOCH: 1
# [Epoch Train: 1] loss: 0.6918, time: 246.00 s
# [Epoch Valid: 1] loss: 0.7153, auc: 0.4947, time: 63.00 s
# auc improved from 0.0000 to 0.4947. Saved model to 'models/FLAIR-e1-loss0.715-auc0.495.pth'
# EPOCH: 2
# [Epoch Train: 2] loss: 0.6938, time: 243.00 s
# [Epoch Valid: 2] loss: 0.7178, auc: 0.5437, time: 60.00 s
# auc improved from 0.4947 to 0.5437. Saved model to 'models/FLAIR-e2-loss0.718-auc0.544.pth'
# EPOCH: 3
# [Epoch Train: 3] loss: 0.6890, time: 249.00 s
# [Epoch Valid: 3] loss: 0.7176, auc: 0.5076, time: 63.00 s
# EPOCH: 4
# [Epoch Train: 4] loss: 0.6846, time: 241.00 s
# [Epoch Valid: 4] loss: 0.7099, auc: 0.5457, time: 61.00 s
# auc improved from 0.5437 to 0.5457. Saved model to 'models/FLAIR-e4-loss0.710-auc0.546.pth'
# EPOCH: 5
# [Epoch Train: 5] loss: 0.6882, time: 239.00 s
# [Epoch Valid: 5] loss: 0.7109, auc: 0.5622, time: 57.00 s
# auc improved from 0.5457 to 0.5622. Saved model to 'models/FLAIR-e5-loss0.711-auc0.562.pth'
# Predict: FLAIR (117, 2)
# /home/christian/miniconda/envs/pytorch/lib/python3.8/site-packages/pandas/core/indexing.py:1667: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = value
# Predict: FLAIR (87, 2)
# (465, 3) (117, 3)
#     BraTS21ID  MGMT_value MRI_Type
# 12         19           0    FLAIR
# 20         30           0    FLAIR
# 22         32           0    FLAIR
# 32         52           1    FLAIR
# 39         61           0    FLAIR
# 465
#     BraTS21ID  MGMT_value MRI_Type
# 12         19           0    FLAIR
# 20         30           0    FLAIR
# 22         32           0    FLAIR
# 32         52           1    FLAIR
# 39         61           0    FLAIR
# 117
# EPOCH: 1
# [Epoch Train: 1] loss: 0.6953, time: 241.00 s
# [Epoch Valid: 1] loss: 0.7208, auc: 0.5193, time: 60.00 s
# auc improved from 0.0000 to 0.5193. Saved model to 'models/FLAIR-e1-loss0.721-auc0.519.pth'
# EPOCH: 2
# [Epoch Train: 2] loss: 0.6929, time: 243.00 s
# [Epoch Valid: 2] loss: 0.7165, auc: 0.5509, time: 73.00 s
# auc improved from 0.5193 to 0.5509. Saved model to 'models/FLAIR-e2-loss0.717-auc0.551.pth'
# EPOCH: 3
# [Epoch Train: 3] loss: 0.6898, time: 249.00 s
# [Epoch Valid: 3] loss: 0.7190, auc: 0.5114, time: 74.00 s
# EPOCH: 4
# [Epoch Train: 4] loss: 0.6907, time: 246.00 s
# [Epoch Valid: 4] loss: 0.7220, auc: 0.4953, time: 59.00 s
# EPOCH: 5
# [Epoch Train: 5] loss: 0.
00 s
# EPOCH: 5
# [Epoch Train: 5] loss: 0.6900, time: 248.00 s
# [Epoch Valid: 5] loss: 0.7088, auc: 0.5586, time: 57.00 s
# Predict: T1wCE (116, 2)
# /home/christian/miniconda/envs/pytorch/lib/python3.8/site-packages/pandas/core/indexing.py:1667: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = value
# Predict: T1wCE (87, 3)
# (466, 3) (116, 3)
#     BraTS21ID  MGMT_value MRI_Type
# 1           2           1    T1wCE
# 3           5           1    T1wCE
# 5           8           1    T1wCE
# 10         17           0    T1wCE
# 13         20           1    T1wCE
# 466
#     BraTS21ID  MGMT_value MRI_Type
# 1           2           1    T1wCE
# 3           5           1    T1wCE
# 5           8           1    T1wCE
# 10         17           0    T1wCE
# 13         20           1    T1wCE
# 116
# EPOCH: 1
# [Epoch Train: 1] loss: 0.6945, time: 234.00 s
# [Epoch Valid: 1] loss: 0.7125, auc: 0.4578, time: 57.00 s
# auc improved from 0.0000 to 0.4578. Saved model to 'models/T1wCE-e1-loss0.713-auc0.458.pth'
# EPOCH: 2
# [Epoch Train: 2] loss: 0.6986, time: 229.00 s
# [Epoch Valid: 2] loss: 0.7099, auc: 0.4727, time: 59.00 s
# auc improved from 0.4578 to 0.4727. Saved model to 'models/T1wCE-e2-loss0.710-auc0.473.pth'
# EPOCH: 3
# [Epoch Train: 3] loss: 0.6962, time: 239.00 s
# [Epoch Valid: 3] loss: 0.7077, auc: 0.5326, time: 65.00 s
# auc improved from 0.4727 to 0.5326. Saved model to 'models/T1wCE-e3-loss0.708-auc0.533.pth'
# EPOCH: 4
# [Epoch Train: 4] loss: 0.6927, time: 240.00 s
# [Epoch Valid: 4] loss: 0.7128, auc: 0.4560, time: 58.00 s
# EPOCH: 5
# [Epoch Train: 5] loss: 0.6930, time: 242.00 s
# [Epoch Valid: 5] loss: 0.7017, auc: 0.5586, time: 64.00 s
# auc improved from 0.5326 to 0.5586. Saved model to 'models/T1wCE-e5-loss0.702-auc0.559.pth'
# Predict: T1wCE (116, 2)
# /home/christian/miniconda/envs/pytorch/lib/python3.8/site-packages/pandas/core/indexing.py:1667: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = value
# Predict: T1wCE (87, 3)
# (465, 3) (117, 3)
#     BraTS21ID  MGMT_value MRI_Type
# 2           3           0      T2w
# 9          14           1      T2w
# 11         18           0      T2w
# 18         26           1      T2w
# 24         35           1      T2w
# 465
#     BraTS21ID  MGMT_value MRI_Type
# 2           3           0      T2w
# 9          14           1      T2w
# 11         18           0      T2w
# 18         26           1      T2w
# 24         35           1      T2w
# 117
# EPOCH: 1
# [Epoch Train: 1] loss: 0.7254, time: 238.00 s
# [Epoch Valid: 1] loss: 0.6957, auc: 0.5155, time: 63.00 s
# auc improved from 0.0000 to 0.5155. Saved model to 'models/T2w-e1-loss0.696-auc0.516.pth'
# EPOCH: 2
# [Epoch Train: 2] loss: 0.7223, time: 257.00 s
# [Epoch Valid: 2] loss: 0.6942, auc: 0.5191, time: 63.00 s
# auc improved from 0.5155 to 0.5191. Saved model to 'models/T2w-e2-loss0.694-auc0.519.pth'
# EPOCH: 3
# [Epoch Train: 3] loss: 0.7146, time: 255.00 s
# [Epoch Valid: 3] loss: 0.7073, auc: 0.5566, time: 59.00 s
# auc improved from 0.5191 to 0.5566. Saved model to 'models/T2w-e3-loss0.707-auc0.557.pth'
# EPOCH: 4
# [Epoch Train: 4] loss: 0.7093, time: 258.00 s
# [Epoch Valid: 4] loss: 0.7027, auc: 0.5328, time: 66.00 s
# EPOCH: 5
# [Epoch Train: 5] loss: 0.7045, time: 243.00 s
# [Epoch Valid: 5] loss: 0.7023, auc: 0.4507, time: 62.00 s
# Predict: T2w (117, 2)
# /home/christian/miniconda/envs/pytorch/lib/python3.8/site-packages/pandas/core/indexing.py:1667: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = value
# Predict: T2w (87, 3)
# (465, 3) (117, 3)
#     BraTS21ID  MGMT_value MRI_Type
# 12         19           0      T2w
# 20         30           0      T2w
# 22         32           0      T2w
# 32         52           1      T2w
# 39         61           0      T2w
# 465
#     BraTS21ID  MGMT_value MRI_Type
# 12         19           0      T2w
# 20         30           0      T2w
# 22         32           0      T2w
# 32         52           1      T2w
# 39         61           0      T2w
# 117
# EPOCH: 1
# [Epoch Train: 1] loss: 0.6948, time: 238.00 s
# [Epoch Valid: 1] loss: 0.7285, auc: 0.4871, time: 66.00 s
# auc improved from 0.0000 to 0.4871. Saved model to 'models/T2w-e1-loss0.729-auc0.487.pth'
# EPOCH: 2
# [Epoch Train: 2] loss: 0.6923, time: 233.00 s
# [Epoch Valid: 2] loss: 0.7264, auc: 0.4438, time: 58.00 s
# EPOCH: 3
# [Epoch Train: 3] loss: 0.6943, time: 234.00 s
# [Epoch Valid: 3] loss: 0.7269, auc: 0.4760, time: 63.00 s
# EPOCH: 4
# [Epoch Train: 4] loss: 0.
pth'
# EPOCH: 5
# [Epoch Train: 5] loss: 0.6986, time: 237.00 s
# [Epoch Valid: 5] loss: 0.7093, auc: 0.5854, time: 65.00 s
# Predict: T2w (116, 2)
# /home/christian/miniconda/envs/pytorch/lib/python3.8/site-packages/pandas/core/indexing.py:1667: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = value
# Predict: T2w (87, 3)
# CPU times: user 12h 2min 44s, sys: 56min 58s, total: 12h 59min 43s
# Wall time: 8h 35min 56s

# %%
x_train = np.swapaxes(np.array(oof_train), 0, 1)
x_test = np.swapaxes(np.array(oof_test), 0, 1)

# %%
len(df), len(x_train), len(x_test)
# Out:
# (582, 582, 87)

# %%
df_test = pd.read_csv(f"{data_directory}/sample_submission.csv")

# %%
for i, mri_type in enumerate(mri_types):
    df[f"level0_{mri_type}_preds"] = x_train[:, i]
    df_test[f"level0_{mri_type}_preds"] = x_test[:, i]

# %%
y = df["MGMT_value"].values
X = df.drop(["MGMT_value"], axis=1)

# %%
params = {
    'learning_rate': [0.03, 0.01, 0.005],
    'n_estimators': [1000, 5000, 10000, 20000],
    'min_child_weight': [1, 5, 10],
    'gamma': [0.5, 1, 1.5, 2, 5],
    'subsample': [0.6, 0.8, 1.0],
    'colsample_bytree': [0.6, 0.8, 1.0],
    'max_depth': [3, 4, 5]
}

# %%
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV

# %%
gbc = xgb.XGBClassifier(
    objective='binary:logistic',
)

# %%
folds = 5
param_comb = 20

skf = StratifiedKFold(n_splits=folds, shuffle=True, random_state=1001)

random_search = RandomizedSearchCV(
    gbc,
    param_distributions=params,
    n_iter=param_comb,
    scoring='roc_auc',
    n_jobs=8,
    cv=skf.split(X, y),
    verbose=10,
    random_state=1001,
    use_label_encoder=False
)

random_search.fit(X, y)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# /home/christian/miniconda/envs/pytorch/lib/python3.8/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [18:12:35] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# RandomizedSearchCV(cv=<generator object _BaseKFold.split at 0x7f76ff417ac0>,
#                    estimator=XGBClassifier(base_score=None, booster=None,
#                                            colsample_bylevel=None,
#                                            colsample_bynode=None,
#                                            colsample_bytree=None, gamma=None,
#                                            gpu_id=None, importance_type='gain',
#                                            interaction_constraints=None,
#                                            learning_rate=None,
#                                            max_delta_step=None, max_depth=None,
#                                            min_child_weight=None, missing...
#                                            subsample=None, tree_method=None,
#                                            validate_parameters=None,
#                                            verbosity=None),
#                    n_iter=20, n_jobs=8,
#                    param_distributions={'colsample_bytree': [0.6, 0.8, 1.0],
#                                         'gamma': [0.5, 1, 1.5, 2, 5],
#                                         'learning_rate': [0.03, 0.01, 0.005],
#                                         'max_depth': [3, 4, 5],
#                                         'min_child_weight': [1, 5, 10],
#                                         'n_estimators': [1000, 5000, 10000,
#                                                          20000],
#                                         'subsample': [0.6, 0.8, 1.0]},
#                    random_state=1001, scoring='roc_auc', verbose=10)
# /home/christian/miniconda/envs/pytorch/lib/python3.8/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /home/christian/miniconda/envs/pytorch/lib/python3.8/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /home/christian/miniconda/envs/pytorch/lib/python3.8/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /home/christian/miniconda/envs/pytorch/lib/python3.8/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /home/christian/miniconda/envs/pytorch/lib/python3.8/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /home/christian/miniconda/envs/pytorch/lib/python3.8/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /home/christian/miniconda/envs/pytorch/lib/python3.8/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /home/christian/miniconda/envs/pytorch/lib/python3.8/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /home/christian/miniconda/envs/pytorch/lib/python3.8/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /home/christian/miniconda/envs/pytorch/lib/python3.8/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /home/christian/miniconda/envs/pytorch/lib/python3.8/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /home/christian/miniconda/envs/pytorch/lib/python3.8/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /home/christian/miniconda/envs/pytorch/lib/python3.8/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /home/christian/miniconda/envs/pytorch/lib/python3.8/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [CV 4/5; 1/20] START colsample_bytree=0.8, gamma=5, learning_rate=0.03, max_depth=4, min_child_weight=1, n_estimators=1000, subsample=0.8
# [17:59:37] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 4/5; 1/20] END colsample_bytree=0.8, gamma=5, learning_rate=0.03, max_depth=4, min_child_weight=1, n_estimators=1000, subsample=0.8;, score=0.408 total time=   8.5s
# [CV 5/5; 2/20] START colsample_bytree=0.6, gamma=0.5, learning_rate=0.005, max_depth=4, min_child_weight=10, n_estimators=20000, subsample=0.8
# [17:59:45] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 5/5; 2/20] END colsample_bytree=0.6, gamma=0.5, learning_rate=0.005, max_depth=4, min_child_weight=10, n_estimators=20000, subsample=0.8;, score=0.491 total time= 2.1min
# [CV 5/5; 4/20] START colsample_bytree=0.8, gamma=1, learning_rate=0.03, max_depth=4, min_child_weight=5, n_estimators=5000, subsample=0.8
# [18:01:53] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 5/5; 4/20] END colsample_bytree=0.8, gamma=1, learning_rate=0.03, max_depth=4, min_child_weight=5, n_estimators=5000, subsample=0.8;, score=0.463 total time=  37.2s
# [CV 5/5; 5/20] START colsample_bytree=0.6, gamma=2, learning_rate=0.005, max_depth=5, min_child_weight=10, n_estimators=20000, subsample=0.8
# [18:02:30] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 5/5; 5/20] END colsample_bytree=0.6, gamma=2, learning_rate=0.005, max_depth=5, min_child_weight=10, n_estimators=20000, subsample=0.8;, score=0.500 total time= 2.5min
# [CV 3/5; 9/20] START colsample_bytree=1.0, gamma=5, learning_rate=0.005, max_depth=3, min_child_weight=1, n_estimators=10000, subsample=1.0
# [18:05:02] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 3/5; 9/20] END colsample_bytree=1.0, gamma=5, learning_rate=0.005, max_depth=3, min_child_weight=1, n_estimators=10000, subsample=1.0;, score=0.569 total time= 1.1min
# [CV 5/5; 9/20] START colsample_bytree=1.0, gamma=5, learning_rate=0.005, max_depth=3, min_child_weight=1, n_estimators=10000, subsample=1.0
# [18:06:07] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 5/5; 9/20] END colsample_bytree=1.0, gamma=5, learning_rate=0.005, max_depth=3, min_child_weight=1, n_estimators=10000, subsample=1.0;, score=0.477 total time= 1.1min
# [CV 5/5; 10/20] START colsample_bytree=0.6, gamma=1.5, learning_rate=0.005, max_depth=4, min_child_weight=1, n_estimators=20000, subsample=0.6
# [18:07:11] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 5/5; 10/20] END colsample_bytree=0.6, gamma=1.5, learning_rate=0.005, max_depth=4, min_child_weight=1, n_estimators=20000, subsample=0.6;, score=0.423 total time= 2.4min
# [CV 1/5; 14/20] START colsample_bytree=0.6, gamma=1, learning_rate=0.03, max_depth=5, min_child_weight=1, n_estimators=1000, subsample=0.6
# [18:09:35] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 1/5; 14/20] END colsample_bytree=0.6, gamma=1, learning_rate=0.03, max_depth=5, min_child_weight=1, n_estimators=1000, subsample=0.6;, score=0.519 total time=  10.3s
# [CV 4/5; 14/20] START colsample_bytree=0.6, gamma=1, learning_rate=0.03, max_depth=5, min_child_weight=1, n_estimators=1000, subsample=0.6
# [18:09:46] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 4/5; 14/20] END colsample_bytree=0.6, gamma=1, learning_rate=0.03, max_depth=5, min_child_weight=1, n_estimators=1000, subsample=0.6;, score=0.396 total time=  10.1s
# [CV 2/5; 15/20] START colsample_bytree=0.8, gamma=1, learning_rate=0.03, max_depth=5, min_child_weight=1, n_estimators=10000, subsample=0.6
# [18:09:56] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 2/5; 15/20] END colsample_bytree=0.8, gamma=1, learning_rate=0.03, max_depth=5, min_child_weight=1, n_estimators=10000, subsample=0.6;, score=0.473 total time= 1.6min
# [CV 2/5; 17/20] START colsample_bytree=1.0, gamma=0.5, learning_rate=0.03, max_depth=3, min_child_weight=10, n_estimators=1000, subsample=0.6
# [18:11:35] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 2/5; 17/20] END colsample_bytree=1.0, gamma=0.5, learning_rate=0.03, max_depth=3, min_child_weight=10, n_estimators=1000, subsample=0.6;, score=0.455 total time=   5.9s
# [CV 4/5; 17/20] START colsample_bytree=1.0, gamma=0.5, learning_rate=0.03, max_depth=3, min_child_weight=10, n_estimators=1000, subsample=0.6
# [18:11:41] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 4/5; 17/20] END colsample_bytree=1.0, gamma=0.5, learning_rate=0.03, max_depth=3, min_child_weight=10, n_estimators=1000, subsample=0.6;, score=0.394 total time=   5.1s
# [CV 1/5; 18/20] START colsample_bytree=0.6, gamma=1, learning_rate=0.03, max_depth=5, min_child_weight=10, n_estimators=1000, subsample=0.8
# [18:11:46] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 1/5; 18/20] END colsample_bytree=0.6, gamma=1, learning_rate=0.03, max_depth=5, min_child_weight=10, n_estimators=1000, subsample=0.8;, score=0.546 total time=   7.6s
# [CV 1/5; 19/20] START colsample_bytree=0.6, gamma=0.5, learning_rate=0.005, max_depth=3, min_child_weight=5, n_estimators=5000, subsample=0.8
# [18:11:54] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 1/5; 19/20] END colsample_bytree=0.6, gamma=0.5, learning_rate=0.005, max_depth=3, min_child_weight=5, n_estimators=5000, subsample=0.8;, score=0.537 total time=  29.8s
# [CV 2/5; 2/20] START colsample_bytree=0.6, gamma=0.5, learning_rate=0.005, max_depth=4, min_child_weight=10, n_estimators=20000, subsample=0.8
# [17:59:38] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 2/5; 2/20] END colsample_bytree=0.6, gamma=0.5, learning_rate=0.005, max_depth=4, min_child_weight=10, n_estimators=20000, subsample=0.8;, score=0.465 total time= 2.1min
# [CV 2/5; 4/20] START colsample_bytree=0.8, gamma=1, learning_rate=0.03, max_depth=4, min_child_weight=5, n_estimators=5000, subsample=0.8
# [18:01:45] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 2/5; 4/20] END colsample_bytree=0.8, gamma=1, learning_rate=0.03, max_depth=4, min_child_weight=5, n_estimators=5000, subsample=0.8;, score=0.491 total time=  36.2s
# [CV 3/5; 5/20] START colsample_bytree=0.6, gamma=2, learning_rate=0.005, max_depth=5, min_child_weight=10, n_estimators=20000, subsample=0.
20] START colsample_bytree=0.8, gamma=1, learning_rate=0.03, max_depth=4, min_child_weight=5, n_estimators=5000, subsample=0.8
# [18:01:51] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 3/5; 4/20] END colsample_bytree=0.8, gamma=1, learning_rate=0.03, max_depth=4, min_child_weight=5, n_estimators=5000, subsample=0.8;, score=0.513 total time=  35.1s
# [CV 4/5; 5/20] START colsample_bytree=0.6, gamma=2, learning_rate=0.005, max_depth=5, min_child_weight=10, n_estimators=20000, subsample=0.8
# [18:02:26] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 4/5; 5/20] END colsample_bytree=0.6, gamma=2, learning_rate=0.005, max_depth=5, min_child_weight=10, n_estimators=20000, subsample=0.8;, score=0.403 total time= 2.4min
# [CV 4/5; 8/20] START colsample_bytree=0.6, gamma=5, learning_rate=0.01, max_depth=4, min_child_weight=5, n_estimators=20000, subsample=0.6
# [18:04:52] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 4/5; 8/20] END colsample_bytree=0.6, gamma=5, learning_rate=0.01, max_depth=4, min_child_weight=5, n_estimators=20000, subsample=0.6;, score=0.400 total time= 2.2min
# [CV 3/5; 10/20] START colsample_bytree=0.6, gamma=1.5, learning_rate=0.005, max_depth=4, min_child_weight=1, n_estimators=20000, subsample=0.6
# [18:07:06] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 3/5; 10/20] END colsample_bytree=0.6, gamma=1.5, learning_rate=0.005, max_depth=4, min_child_weight=1, n_estimators=20000, subsample=0.6;, score=0.517 total time= 2.4min
# [CV 5/5; 13/20] START colsample_bytree=0.8, gamma=1.5, learning_rate=0.01, max_depth=3, min_child_weight=5, n_estimators=20000, subsample=1.0
# [18:09:32] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 5/5; 13/20] END colsample_bytree=0.8, gamma=1.5, learning_rate=0.01, max_depth=3, min_child_weight=5, n_estimators=20000, subsample=1.0;, score=0.410 total time= 2.0min
# [CV 1/5; 17/20] START colsample_bytree=1.0, gamma=0.5, learning_rate=0.03, max_depth=3, min_child_weight=10, n_estimators=1000, subsample=0.6
# [18:11:32] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 1/5; 17/20] END colsample_bytree=1.0, gamma=0.5, learning_rate=0.03, max_depth=3, min_child_weight=10, n_estimators=1000, subsample=0.6;, score=0.530 total time=   5.9s
# [CV 3/5; 17/20] START colsample_bytree=1.0, gamma=0.5, learning_rate=0.03, max_depth=3, min_child_weight=10, n_estimators=1000, subsample=0.6
# [18:11:38] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 3/5; 17/20] END colsample_bytree=1.0, gamma=0.5, learning_rate=0.03, max_depth=3, min_child_weight=10, n_estimators=1000, subsample=0.6;, score=0.559 total time=   6.5s
# [CV 5/5; 17/20] START colsample_bytree=1.0, gamma=0.5, learning_rate=0.03, max_depth=3, min_child_weight=10, n_estimators=1000, subsample=0.6
# [18:11:45] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 5/5; 17/20] END colsample_bytree=1.0, gamma=0.5, learning_rate=0.03, max_depth=3, min_child_weight=10, n_estimators=1000, subsample=0.6;, score=0.496 total time=   5.3s
# [CV 4/5; 18/20] START colsample_bytree=0.6, gamma=1, learning_rate=0.03, max_depth=5, min_child_weight=10, n_estimators=1000, subsample=0.8
# [18:11:50] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 4/5; 18/20] END colsample_bytree=0.6, gamma=1, learning_rate=0.03, max_depth=5, min_child_weight=10, n_estimators=1000, subsample=0.8;, score=0.397 total time=   6.8s
# [CV 4/5; 19/20] START colsample_bytree=0.6, gamma=0.5, learning_rate=0.005, max_depth=3, min_child_weight=5, n_estimators=5000, subsample=0.8
# [18:11:57] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 4/5; 19/20] END colsample_bytree=0.6, gamma=0.5, learning_rate=0.005, max_depth=3, min_child_weight=5, n_estimators=5000, subsample=0.8;, score=0.410 total time=  25.5s
# [CV 4/5; 20/20] START colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=5000, subsample=0.8
# [18:12:23] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 4/5; 20/20] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=5000, subsample=0.8;, score=0.411 total time=  11.7s
# [CV 3/5; 1/20] START colsample_bytree=0.8, gamma=5, learning_rate=0.03, max_depth=4, min_child_weight=1, n_estimators=1000, subsample=0.8
# [17:59:37] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 3/5; 1/20] END colsample_bytree=0.8, gamma=5, learning_rate=0.03, max_depth=4, min_child_weight=1, n_estimators=1000, subsample=0.8;, score=0.528 total time=   8.7s
# [CV 1/5; 3/20] START colsample_bytree=0.6, gamma=0.5, learning_rate=0.005, max_depth=3, min_child_weight=1, n_estimators=20000, subsample=1.0
# [17:59:46] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 1/5; 3/20] END colsample_bytree=0.6, gamma=0.5, learning_rate=0.005, max_depth=3, min_child_weight=1, n_estimators=20000, subsample=1.0;, score=0.570 total time= 2.0min
# [CV 1/5; 4/20] START colsample_bytree=0.8, gamma=1, learning_rate=0.03, max_depth=4, min_child_weight=5, n_estimators=5000, subsample=0.8
# [18:01:43] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 1/5; 4/20] END colsample_bytree=0.8, gamma=1, learning_rate=0.03, max_depth=4, min_child_weight=5, n_estimators=5000, subsample=0.8;, score=0.535 total time=  36.4s
# [CV 2/5; 5/20] START colsample_bytree=0.6, gamma=2, learning_rate=0.005, max_depth=5, min_child_weight=10, n_estimators=20000, subsample=0.8
# [18:02:19] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 2/5; 5/20] END colsample_bytree=0.6, gamma=2, learning_rate=0.005, max_depth=5, min_child_weight=10, n_estimators=20000, subsample=0.8;, score=0.459 total time= 2.4min
# [CV 2/5; 8/20] START colsample_bytree=0.6, gamma=5, learning_rate=0.01, max_depth=4, min_child_weight=5, n_estimators=20000, subsample=0.6
# [18:04:46] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 2/5; 8/20] END colsample_bytree=0.6, gamma=5, learning_rate=0.01, max_depth=4, min_child_weight=5, n_estimators=20000, subsample=0.6;, score=0.459 total time= 2.4min
# [CV 1/5; 11/20] START colsample_bytree=1.0, gamma=0.5, learning_rate=0.03, max_depth=3, min_child_weight=10, n_estimators=5000, subsample=1.0
# [18:07:11] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 1/5; 11/20] END colsample_bytree=1.0, gamma=0.5, learning_rate=0.03, max_depth=3, min_child_weight=10, n_estimators=5000, subsample=1.0;, score=0.562 total time=  31.1s
# [CV 4/5; 11/20] START colsample_bytree=1.0, gamma=0.5, learning_rate=0.03, max_depth=3, min_child_weight=10, n_estimators=5000, subsample=1.0
# [18:07:43] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 4/5; 11/20] END colsample_bytree=1.0, gamma=0.5, learning_rate=0.03, max_depth=3, min_child_weight=10, n_estimators=5000, subsample=1.0;, score=0.419 total time=  28.4s
# [CV 3/5; 12/20] START colsample_bytree=0.6, gamma=2, learning_rate=0.005, max_depth=3, min_child_weight=10, n_estimators=1000, subsample=1.0
# [18:08:11] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 3/5; 12/20] END colsample_bytree=0.6, gamma=2, learning_rate=0.005, max_depth=3, min_child_weight=10, n_estimators=1000, subsample=1.0;, score=0.551 total time=   6.1s
# [CV 5/5; 12/20] START colsample_bytree=0.6, gamma=2, learning_rate=0.005, max_depth=3, min_child_weight=10, n_estimators=1000, subsample=1.0
# [18:08:18] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 5/5; 12/20] END colsample_bytree=0.6, gamma=2, learning_rate=0.005, max_depth=3, min_child_weight=10, n_estimators=1000, subsample=1.0;, score=0.475 total time=   6.3s
# [CV 3/5; 13/20] START colsample_bytree=0.8, gamma=1.5, learning_rate=0.01, max_depth=3, min_child_weight=5, n_estimators=20000, subsample=1.0
# [18:08:24] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 3/5; 13/20] END colsample_bytree=0.8, gamma=1.5, learning_rate=0.01, max_depth=3, min_child_weight=5, n_estimators=20000, subsample=1.0;, score=0.524 total time= 1.9min
# [CV 5/5; 15/20] START colsample_bytree=0.8, gamma=1, learning_rate=0.03, max_depth=5, min_child_weight=1, n_estimators=10000, subsample=0.6
# [18:10:18] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 5/5; 15/20] END colsample_bytree=0.8, gamma=1, learning_rate=0.03, max_depth=5, min_child_weight=1, n_estimators=10000, subsample=0.6;, score=0.424 total time= 1.5min
# [CV 2/5; 18/20] START colsample_bytree=0.6, gamma=1, learning_rate=0.03, max_depth=5, min_child_weight=10, n_estimators=1000, subsample=0.8
# [18:11:47] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 2/5; 18/20] END colsample_bytree=0.6, gamma=1, learning_rate=0.03, max_depth=5, min_child_weight=10, n_estimators=1000, subsample=0.8;, score=0.456 total time=   7.4s
# [CV 2/5; 19/20] START colsample_bytree=0.6, gamma=0.5, learning_rate=0.005, max_depth=3, min_child_weight=5, n_estimators=5000, subsample=0.8
# [18:11:55] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 2/5; 19/20] END colsample_bytree=0.6, gamma=0.5, learning_rate=0.005, max_depth=3, min_child_weight=5, n_estimators=5000, subsample=0.8;, score=0.461 total time=  28.7s
# [CV 5/5; 20/20] START colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=5000, subsample=0.8
# [18:12:23] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV 5/5; 20/20] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=5000, subsample=0.8;, score=0.407 total time=  11.3s

# %%
print('\n All results:')
print(random_search.cv_results_)
print('\n Best estimator:')
print(random_search.best_estimator_)
print('\n Best normalized gini score for %d-fold search with %d parameter combinations:' % (folds, param_comb))
print(random_search.best_score_ * 2 - 1)
print('\n Best hyperparameters:')
print(random_search.best_params_)
results = pd.DataFrame(random_search.cv_results_)
results.to_csv('xgb-random-grid-search-results-01.csv', index=False)
# Out:
#  All results:
# {'mean_fit_time': array([  8.45945172, 128.59850683, 117.41013484,  37.23838453,
#        148.21885076,  35.02557316,  28.78415365, 144.61310549,
#         66.04030118, 153.94238405,  30.7680419 ,   6.09051623,
#        118.02095752,   9.68533225,  91.58562684,  42.63578987,
#          5.63228321,   7.54920316,  28.26178298,  21.18094015]), 'std_fit_time': array([ 0.19811682,  3.22622819,  4.9090115 ,  2.27998609,  2.10127114,
#         2.15048501,  3.34122675,  7.4021175 ,  5.23772357, 10.16585642,
#         1.36103495,  0.26658426,  5.17889558,  1.05495977,  6.34927054,
#         3.05479598,  0.48150815,  0.49532012,  2.02593115,  7.93609103]), 'mean_score_time': array([0.05082045, 0.16510553, 0.10070386, 0.08195767, 0.12110496,
#        0.10722175, 0.0931139 , 0.08993969, 0.07313018, 0.16143746,
#        0.0744483 , 0.04271483, 0.08335099, 0.07417793, 0.0867589 ,
#        0.06744432, 0.07890992, 0.05788221, 0.08633633, 0.03667912]), 'std_score_time': array([0.029465  , 0.04332207, 0.01306493, 0.01605651, 0.03581589,
#        0.01529823, 0.02336524, 0.02426446, 0.01122476, 0.02118344,
#        0.01596644, 0.01857953, 0.00820751, 0.03165978, 0.0167092 ,
#        0.01352591, 0.01737926, 0.01129804, 0.0162577 , 0.03516366]), 'param_subsample': masked_array(data=[0.8, 0.8, 1.0, 0.8, 0.8, 0.6, 0.6, 0.6, 1.0, 0.6, 1.0,
#                    1.0, 1.0, 0.6, 0.6, 1.0, 0.6, 0.8, 0.8, 0.8],
#              mask=[False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False],
#        fill_value='?',
#             dtype=object), 'param_n_estimators': masked_array(data=[1000, 20000, 20000, 5000, 20000, 5000, 5000, 20000,
#                    10000, 20000, 5000, 1000, 20000, 1000, 10000, 5000,
#                    1000, 1000, 5000, 5000],
#              mask=[False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False],
#        fill_value='?',
#             dtype=object), 'param_min_child_weight': masked_array(data=[1, 10, 1, 5, 10, 10, 1, 5, 1, 1, 10, 10, 5, 1, 1, 1,
#                    10, 10, 5, 1],
#              mask=[False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False],
#        fill_value='?',
#             dtype=object), 'param_max_depth': masked_array(data=[4, 4, 3, 4, 5, 4, 3, 4, 3, 4, 3, 3, 3, 5, 5, 5, 3, 5,
#                    3, 3],
#              mask=[False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False],
#        fill_value='?',
#             dtype=object), 'param_learning_rate': masked_array(data=[0.03, 0.005, 0.005, 0.03, 0.005, 0.005, 0.005, 0.01,
#                    0.005, 0.005, 0.03, 0.005, 0.01, 0.03, 0.03, 0.01,
#                    0.03, 0.03, 0.005, 0.01],
#              mask=[False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False],
#        fill_value='?',
#             dtype=object), 'param_gamma': masked_array(data=[5, 0.5, 0.5, 1, 2, 1, 1.5, 5, 5, 1.5, 0.5, 2, 1.5, 1,
#                    1, 1.5, 0.5, 1, 0.5, 1],
#              mask=[False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False],
#        fill_value='?',
#             dtype=object), 'param_colsample_bytree': masked_array(data=[0.8, 0.6, 0.6, 0.8, 0.6, 0.6, 0.6, 0.6, 1.0, 0.6, 1.0,
#                    0.6, 0.8, 0.6, 0.8, 0.6, 1.0, 0.6, 0.6, 0.6],
#              mask=[False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False],
#        fill_value='?',
#             dtype=object), 'params': [{'subsample': 0.8, 'n_estimators': 1000, 'min_child_weight': 1, 'max_depth': 4, 'learning_rate': 0.03, 'gamma': 5, 'colsample_bytree': 0.8}, {'subsample': 0.8, 'n_estimators': 20000, 'min_child_weight': 10, 'max_depth': 4, 'learning_rate': 0.005, 'gamma': 0.5, 'colsample_bytree': 0.6}, {'subsample': 1.0, 'n_estimators': 20000, 'min_child_weight': 1, 'max_depth': 3, 'learning_rate': 0.005, 'gamma': 0.5, 'colsample_bytree': 0.6}, {'subsample': 0.8, 'n_estimators': 5000, 'min_child_weight': 5, 'max_depth': 4, 'learning_rate': 0.03, 'gamma': 1, 'colsample_bytree': 0.8}, {'subsample': 0.8, 'n_estimators': 20000, 'min_child_weight': 10, 'max_depth': 5, 'learning_rate': 0.005, 'gamma': 2, 'colsample_bytree': 0.6}, {'subsample': 0.6, 'n_estimators': 5000, 'min_child_weight': 10, 'max_depth': 4, 'learning_rate': 0.005, 'gamma': 1, 'colsample_bytree': 0.6}, {'subsample': 0.6, 'n_estimators': 5000, 'min_child_weight': 1, 'max_depth': 3, 'learning_rate': 0.005, 'gamma': 1.5, 'colsample_bytree': 0.6}, {'subsample': 0.6, 'n_estimators': 20000, 'min_child_weight': 5, 'max_depth': 4, 'learning_rate': 0.01, 'gamma': 5, 'colsample_bytree': 0.6}, {'subsample': 1.0, 'n_estimators': 10000, 'min_child_weight': 1, 'max_depth': 3, 'learning_rate': 0.005, 'gamma': 5, 'colsample_bytree': 1.0}, {'subsample': 0.6, 'n_estimators': 20000, 'min_child_weight': 1, 'max_depth': 4, 'learning_rate': 0.005, 'gamma': 1.5, 'colsample_bytree': 0.6}, {'subsample': 1.0, 'n_estimators': 5000, 'min_child_weight': 10, 'max_depth': 3, 'learning_rate': 0.03, 'gamma': 0.5, 'colsample_bytree': 1.0}, {'subsample': 1.0, 'n_estimators': 1000, 'min_child_weight': 10, 'max_depth': 3, 'learning_rate': 0.005, 'gamma': 2, 'colsample_bytree': 0.6}, {'subsample': 1.0, 'n_estimators': 20000, 'min_child_weight': 5, 'max_depth': 3, 'learning_rate': 0.01, 'gamma': 1.5, 'colsample_bytree': 0.8}, {'subsample': 0.6, 'n_estimators': 1000, 'min_child_weight': 1, 'max_depth': 5, 'learning_rate': 0.03, 'gamma': 1, 'colsample_bytree': 0.6}, {'subsample': 0.6, 'n_estimators': 10000, 'min_child_weight': 1, 'max_depth': 5, 'learning_rate': 0.03, 'gamma': 1, 'colsample_bytree': 0.8}, {'subsample': 1.0, 'n_estimators': 5000, 'min_child_weight': 1, 'max_depth': 5, 'learning_rate': 0.01, 'gamma': 1.5, 'colsample_bytree': 0.6}, {'subsample': 0.6, 'n_estimators': 1000, 'min_child_weight': 10, 'max_depth': 3, 'learning_rate': 0.03, 'gamma': 0.5, 'colsample_bytree': 1.0}, {'subsample': 0.8, 'n_estimators': 1000, 'min_child_weight': 10, 'max_depth': 5, 'learning_rate': 0.03, 'gamma': 1, 'colsample_bytree': 0.6}, {'subsample': 0.8, 'n_estimators': 5000, 'min_child_weight': 5, 'max_depth': 3, 'learning_rate': 0.005, 'gamma': 0.5, 'colsample_bytree': 0.6}, {'subsample': 0.8, 'n_estimators': 5000, 'min_child_weight': 1, 'max_depth': 3, 'learning_rate': 0.01, 'gamma': 1, 'colsample_bytree': 0.6}], 'split0_test_score': array([0.56510264, 0.54222874, 0.56979472, 0.53460411, 0.54442815,
#        0.5414956 , 0.53695015, 0.55337243, 0.55      , 0.51876833,
#        0.56202346, 0.58519062, 0.57565982, 0.51906158, 0.5202346 ,
#        0.56217009, 0.52991202, 0.54618768, 0.5372434 , 0.5143695 ]), 'split1_test_score': array([0.47336066, 0.46457845, 0.5161007 , 0.49092506, 0.45872365,
#        0.43530445, 0.46282201, 0.45930913, 0.50761124, 0.47599532,
#        0.46604215, 0.47043326, 0.4970726 , 0.48272834, 0.47336066,
#        0.49648712, 0.45491803, 0.45638173, 0.46077283, 0.4721897 ]), 'split2_test_score': array([0.52846498, 0.53561848, 0.53949329, 0.51296572, 0.52846498,
#        0.56065574, 0.53323398, 0.52876304, 0.56870343, 0.51684054,
#        0.52846498, 0.55067064, 0.52444113, 0.50938897, 0.5171386 ,
#        0.47034277, 0.55886736, 0.52846498, 0.52101341, 0.52846498]), 'split3_test_score': array([0.40804769, 0.4071535 , 0.41609538, 0.41579732, 0.40298063,
#        0.40387481, 0.409538  , 0.39970194, 0.51147541, 0.4071535 ,
#        0.41877794, 0.45603577, 0.45767511, 0.39582712, 0.41162444,
#        0.43070045, 0.39433681, 0.39701937, 0.41043219, 0.41102832]), 'split4_test_score': array([0.4071535 , 0.49090909, 0.44560358, 0.46259314, 0.50014903,
#        0.52160954, 0.42086438, 0.47690015, 0.47675112, 0.42295082,
#        0.44798808, 0.47540984, 0.41043219, 0.41847988, 0.42444113,
#        0.39135618, 0.49597615, 0.48703428, 0.42593145, 0.40745156]), 'mean_test_score': array([0.47642589, 0.48809765, 0.49741753, 0.48337707, 0.48694929,
#        0.49258803, 0.4726817 , 0.48360934, 0.52290824, 0.4683417 ,
#        0.48465932, 0.50754802, 0.49305617, 0.46509718, 0.46935989,
#        0.47021132, 0.48680208, 0.48301761, 0.47107866, 0.46670081]), 'std_test_score': array([0.06333288, 0.04960124, 0.05771632, 0.04136584, 0.05108626,
#        0.06167472, 0.05397478, 0.05400317, 0.03263848, 0.0463851 ,
#        0.05279371, 0.05089561, 0.0563969 , 0.04930779, 0.04525069,
#        0.05818263, 0.05779698, 0.05324889, 0.05038597, 0.05045224]), 'rank_test_score': array([13,  6,  3, 11,  7,  5, 14, 10,  1, 18,  9,  2,  4, 20, 17, 16,  8,
#        12, 15, 19], dtype=int32)}
#
#  Best estimator:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1.0, gamma=5, gpu_id=-1,
#               importance_type='gain', interaction_constraints='',
#               learning_rate=0.005, max_delta_step=0, max_depth=3,
#               min_child_weight=1, missing=nan, monotone_constraints='()',
#               n_estimators=10000, n_jobs=16, num_parallel_tree=1,
#               random_state=0, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#               subsample=1.0, tree_method='exact', validate_parameters=1,
#               verbosity=None)
#
#  Best normalized gini score for 5-fold search with 20 parameter combinations:
# 0.04581647860336391
#
#  Best hyperparameters:
# {'subsample': 1.0, 'n_estimators': 10000, 'min_child_weight': 1, 'max_depth': 3, 'learning_rate': 0.005, 'gamma': 5, 'colsample_bytree': 1.0}

# %%
results
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        8.459452      0.198117         0.050820        0.029465
# 1      128.598507      3.226228         0.165106        0.043322
# 2      117.410135      4.909012         0.100704        0.013065
# 3       37.238385      2.279986         0.081958        0.016057
# 4      148.218851      2.101271         0.121105        0.035816
# 5       35.025573      2.150485         0.107222        0.015298
# 6       28.784154      3.341227         0.093114        0.023365
# 7      144.613105      7.402118         0.089940        0.024264
# 8       66.040301      5.237724         0.073130        0.011225
# 9      153.942384     10.165856         0.161437        0.021183
# 10      30.768042      1.361035         0.074448        0.015966
# 11       6.090516      0.266584         0.042715        0.018580
# 12     118.020958      5.178896         0.083351        0.008208
# 13       9.685332      1.054960         0.074178        0.031660
# 14      91.585627      6.349271         0.086759        0.016709
# 15      42.635790      3.054796         0.067444        0.013526
# 16       5.632283      0.481508         0.078910        0.017379
# 17       7.549203      0.495320         0.057882        0.011298
# 18      28.261783      2.025931         0.086336        0.016258
# 19      21.180940      7.936091         0.036679        0.035164
#
#    param_subsample param_n_estimators param_min_child_weight param_max_depth  \
# 0              0.8               1000                      1               4
# 1              0.8              20000                     10               4
# 2              1.0              20000                      1               3
# 3              0.8               5000                      5               4
# 4              0.8              20000                     10               5
# 5              0.6               5000                     10               4
# 6              0.6               5000                      1               3
# 7              0.6              20000                      5               4
# 8              1.0              10000                      1               3
# 9              0.6              20000                      1               4
# 10             1.0               5000                     10               3
# 11             1.0               1000                     10               3
# 12             1.0              20000                      5               3
# 13             0.6               1000                      1               5
# 14             0.6              10000                      1               5
# 15             1.0               5000                      1               5
# 16             0.6               1000                     10               3
# 17             0.8               1000                     10               5
# 18             0.8               5000                      5               3
# 19             0.8               5000                      1               3
#
#    param_learning_rate param_gamma param_colsample_bytree  \
# 0                 0.03           5                    0.8
# 1                0.005         0.5                    0.6
# 2                0.005         0.5                    0.6
# 3                 0.03           1                    0.8
# 4                0.005           2                    0.6
# 5                0.005           1                    0.6
# 6                0.005         1.5                    0.6
# 7                 0.01           5                    0.6
# 8                0.005           5                    1.0
# 9                0.005         1.5                    0.6
# 10                0.03         0.5                    1.0
# 11               0.005           2                    0.6
# 12                0.01         1.5                    0.8
# 13                0.03           1                    0.6
# 14                0.03           1                    0.8
# 15                0.01         1.5                    0.6
# 16                0.03         0.5                    1.0
# 17                0.03           1                    0.6
# 18               0.005         0.5                    0.6
# 19                0.01           1                    0.6
#
#                                                params  split0_test_score  \
# 0   {'subsample': 0.8, 'n_estimators': 1000, 'min_...           0.565103
# 1   {'subsample': 0.8, 'n_estimators': 20000, 'min...           0.542229
# 2   {'subsample': 1.0, 'n_estimators': 20000, 'min...           0.569795
# 3   {'subsample': 0.8, 'n_estimators': 5000, 'min_...           0.534604
# 4   {'subsample': 0.8, 'n_estimators': 20000, 'min...           0.544428
# 5   {'subsample': 0.6, 'n_estimators': 5000, 'min_...           0.541496
# 6   {'subsample': 0.6, 'n_estimators': 5000, 'min_...           0.536950
# 7   {'subsample': 0.6, 'n_estimators': 20000, 'min...           0.553372
# 8   {'subsample': 1.0, 'n_estimators': 10000, 'min...           0.550000
# 9   {'subsample': 0.6, 'n_estimators': 20000, 'min...           0.518768
# 10  {'subsample': 1.0, 'n_estimators': 5000, 'min_...           0.562023
# 11  {'subsample': 1.0, 'n_estimators': 1000, 'min_...           0.585191
# 12  {'subsample': 1.0, 'n_estimators': 20000, 'min...           0.575660
# 13  {'subsample': 0.6, 'n_estimators': 1000, 'min_...           0.519062
# 14  {'subsample': 0.6, 'n_estimators': 10000, 'min...           0.520235
# 15  {'subsample': 1.0, 'n_estimators': 5000, 'min_...           0.562170
# 16  {'subsample': 0.6, 'n_estimators': 1000, 'min_...           0.529912
# 17  {'subsample': 0.8, 'n_estimators': 1000, 'min_...           0.546188
# 18  {'subsample': 0.8, 'n_estimators': 5000, 'min_...           0.537243
# 19  {'subsample': 0.8, 'n_estimators': 5000, 'min_...           0.514370
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.473361           0.528465           0.408048
# 1            0.464578           0.535618           0.407154
# 2            0.516101           0.539493           0.416095
# 3            0.490925           0.512966           0.415797
# 4            0.458724           0.528465           0.402981
# 5            0.435304           0.560656           0.403875
# 6            0.462822           0.533234           0.409538
# 7            0.459309           0.528763           0.399702
# 8            0.507611           0.568703           0.511475
# 9            0.475995           0.516841           0.407154
# 10           0.466042           0.528465           0.418778
# 11           0.470433           0.550671           0.456036
# 12           0.497073           0.524441           0.457675
# 13           0.482728           0.509389           0.395827
# 14           0.473361           0.517139           0.411624
# 15           0.496487           0.470343           0.430700
# 16           0.454918           0.558867           0.394337
# 17           0.456382           0.528465           0.397019
# 18           0.460773           0.521013           0.410432
# 19           0.472190           0.528465           0.411028
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.407154         0.476426        0.063333               13
# 1            0.490909         0.488098        0.049601                6
# 2            0.445604         0.497418        0.057716                3
# 3            0.462593         0.483377        0.041366               11
# 4            0.500149         0.486949        0.051086                7
# 5            0.521610         0.492588        0.061675                5
# 6            0.420864         0.472682        0.053975               14
# 7            0.476900         0.483609        0.054003               10
# 8            0.476751         0.522908        0.032638                1
# 9            0.422951         0.468342        0.046385               18
# 10           0.447988         0.484659        0.052794                9
# 11           0.475410         0.507548        0.050896                2
# 12           0.410432         0.493056        0.056397                4
# 13           0.418480         0.465097        0.049308               20
# 14           0.424441         0.469360        0.045251               17
# 15           0.391356         0.470211        0.058183               16
# 16           0.495976         0.486802        0.057797                8
# 17           0.487034         0.483018        0.053249               12
# 18           0.425931         0.471079        0.050386               15
# 19           0.407452         0.466701        0.050452               19

# %%
x_test = df_test.copy()
x_test = x_test.drop(["MGMT_value"], axis=1)

# %%
test_preds = random_search.predict_proba(x_test)

# %%
test_preds = test_preds[:,1]
test_preds[:4]
# Out:
# array([0.5456323, 0.5456323, 0.5456323, 0.5456323], dtype=float32)

# %%
# auc = roc_auc_score(y_valid, val_preds)
# print(f"Validation ensemble AUC: {auc:.4f}")
sns.displot(test_preds)

# %% [markdown]
# **Submission**

# %%
submission = pd.read_csv(f"{data_directory}/sample_submission.csv")
submission["MGMT_value"] = test_preds
submission.to_csv("submission.csv")
